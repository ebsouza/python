# %% [markdown]
# **1. Importando a biblioteca PANDAS**

# %%
import pandas as pd

# %% [markdown]
# **2. Leitura de um arquivo csv**

# %%
csv_file = "https://raw.githubusercontent.com/ebsouza/python/master/data/StudentsPerformance.csv"
df = pd.read_csv(csv_file)
df
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]

# %% [markdown]
# **3. Estatística das variáveis numéricas**

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# **4. Exibindo apenas colunas específicas**

# %%
df[['parental level of education', 'math score']]
# Out:
#     parental level of education  math score
# 0             bachelor's degree          72
# 1                  some college          69
# 2               master's degree          90
# 3            associate's degree          47
# 4                  some college          76
# ..                          ...         ...
# 995             master's degree          88
# 996                 high school          62
# 997                 high school          59
# 998                some college          68
# 999                some college          77
#
# [1000 rows x 2 columns]

# %% [markdown]
# **5. Acessando série numérica de coluna 'math score'**

# %%
print(" >>> Série numérica: \n\n", df['math score'])

print("\n")

print(" >>> Tipo do dado: \n\n", type(df['math score']))
# Out:
#  >>> Série numérica:
#
#  0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64
#
#
#  >>> Tipo do dado:
#
#  <class 'pandas.core.series.Series'>

# %% [markdown]
# **6. Ordenação do dataframe tendo a coluna 'math score' como referência**

# %%
"""
Para ordenar em ordem crescente, basta declarar "df.sort_values('math score')"

Este comando não modifica o dataframe referenciado por "df"
"""
df.sort_values('math score', ascending=False)
# Out:
#      gender race/ethnicity  ... reading score writing score
# 962  female        group E  ...           100           100
# 625    male        group D  ...            97            99
# 458  female        group E  ...           100           100
# 623    male        group A  ...            96            86
# 451  female        group E  ...            92            97
# ..      ...            ...  ...           ...           ...
# 145  female        group C  ...            39            33
# 787  female        group B  ...            38            32
# 17   female        group B  ...            32            28
# 980  female        group B  ...            24            23
# 59   female        group C  ...            17            10
#
# [1000 rows x 8 columns]

# %% [markdown]
# **7. Criando um novo score baseado em 'math score', 'reading score' e 'writing score'.**
#
# **[Fórmula de 'new score']**
#
# **new score = (30% x 'math score') + (50% x 'reading score') + (20% x 'writing score')**

# %%
df['new score'] = 0.3*df['math score'] + 0.5*df['reading score'] + 0.2*df['writing score']

df
# Out:
#      gender race/ethnicity  ... writing score new score
# 0    female        group B  ...            74      72.4
# 1    female        group C  ...            88      83.3
# 2    female        group B  ...            93      93.1
# 3      male        group A  ...            44      51.4
# 4      male        group C  ...            75      76.8
# ..      ...            ...  ...           ...       ...
# 995  female        group E  ...            95      94.9
# 996    male        group C  ...            55      57.1
# 997  female        group C  ...            65      66.2
# 998  female        group D  ...            77      74.8
# 999  female        group D  ...            86      83.3
#
# [1000 rows x 9 columns]

# %% [markdown]
# **8. Criando subdataframe: estudantes com 'new score' maior que 80**

# %%
"""
Apenas 200 estudantes possuem 'new score' maior que 80
"""

sub_dataframe = df[df['new score'] > 80]

sub_dataframe
# Out:
#      gender race/ethnicity  ... writing score new score
# 1    female        group C  ...            88      83.3
# 2    female        group B  ...            93      93.1
# 6    female        group B  ...            92      92.3
# 16     male        group C  ...            86      88.1
# 34     male        group E  ...            82      89.0
# ..      ...            ...  ...           ...       ...
# 982    male        group B  ...            86      83.4
# 983  female        group A  ...            91      85.1
# 990    male        group E  ...            75      81.3
# 995  female        group E  ...            95      94.9
# 999  female        group D  ...            86      83.3
#
# [200 rows x 9 columns]

# %% [markdown]
# **9. Histograma de 'new score'**

# %%
df['new score'].plot.hist()

# %% [markdown]
# **10. Gráfico de dispersão 'new score' x 'reading score'**

# %%
df.plot.scatter(x='new score',y='reading score')

# %% [markdown]
# **11. Correlação entre os scores**

# %%
df[['math score', 'reading score', 'writing score', 'new score']].corr(method='pearson')
# Out:
#                math score  reading score  writing score  new score
# math score       1.000000       0.817580       0.802642   0.911470
# reading score    0.817580       1.000000       0.954598   0.979263
# writing score    0.802642       0.954598       1.000000   0.960873
# new score        0.911470       0.979263       0.960873   1.000000
